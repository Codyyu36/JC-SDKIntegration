# %%
import os
import sys 
# Get the current directory
current_directory = os.getcwd()
print(f"Current Directory: {current_directory}")

# List the files in the current directory
files_in_directory = os.listdir(current_directory)
print(f"Files in Directory: {files_in_directory}")

print(sys.path)
# Out:
# Current Directory: /mnt/c/Users/alada/JC_Code/JC-SDKIntegration
# Files in Directory: ['.git', '.gitignore', '.idea', '.ipynb_checkpoints', 'CameraCodeFW151', 'JcSmartDevice2.0.dll', 'JcSmartDevicePyd.pyd', 'patterns', 'PGCode', 'PyQt5Demo', 'README.md', 'RGBIntegrationScript.cpp', 'RGBIntegrationScript_copy.cpp', 'SDK&Demo_V2.5.1.230517', 'SDKIntegrationConfig.csv', 'SDKIntegrationScript.ipynb', 'test1.xlsx', 'test_tcp.py.txt']
# ['/mnt/c/Users/alada/JC_Code/JC-SDKIntegration', '/home/aladarmiao/miniconda3/envs/tf/lib/python39.zip', '/home/aladarmiao/miniconda3/envs/tf/lib/python3.9', '/home/aladarmiao/miniconda3/envs/tf/lib/python3.9/lib-dynload', '', '/home/aladarmiao/miniconda3/envs/tf/lib/python3.9/site-packages']

# %%
request_bytes = bytes.fromhex('02 53 50 2C 43 2C 2C 2C 31 2C 31 2C 31 2C 30 03')
print(request_bytes)
# Out:
# b'\x02SP,C,,,1,1,1,0\x03'

# %%
from . import JcSmartDevicePyd

# Call the function
sDevSn = "61CF-02"
param = JcSmartDevicePyd.init_device(sDevSn.encode())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from . import JcSmartDevicePyd
#       3 # Call the function
#       4 sDevSn = "61CF-02"
#
# ImportError: attempted relative import with no known parent package

# %%
import ctypes
# Define the required structures and function signatures
# class JcCmdInDataBase(ctypes.Structure):
#     pass

# class JcInitDevice(ctypes.Structure):
#     _fields_ = [
#         ("base", JcCmdInDataBase),
#         ("m_strDeviceSN", ctypes.c_char_p)
#     ]

dll_path = "/mnt/c/Users/alada/JC_Code/JC-SDKIntegration/JcSmartDevice2.0.dll"
dll = ctypes.cdll.LoadLibrary(dll_path)

# # Define the function with the appropriate argument and return types
# init_device = dll.JcInitDevice
# init_device.argtypes = [ctypes.c_char_p]
# init_device.restype = ctypes.c_void_p

# Call the function
sDevSn = "61CF-02"
param = JcSmartDevicePyd.init_device(sDevSn.encode())



# This is why it's frequently useful to supply the information with your
# original question: what version of Python, and what OS... 
# Try going back to where you downloaded this file, and see if you can get
# the one for your OS.
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 13
#       2 # Define the required structures and function signatures
#       3 # class JcCmdInDataBase(ctypes.Structure):
#       4 #     pass
#    (...)
#       9 #         ("m_strDeviceSN", ctypes.c_char_p)
#      10 #     ]
#      12 dll_path = "/mnt/c/Users/alada/JC-Code/JC-SDKIntegration/JcSmartDevice2.0.dll"
# ---> 13 dll = ctypes.cdll.LoadLibrary(dll_path)
#      15 # # Define the function with the appropriate argument and return types
#      16 # init_device = dll.JcInitDevice
#      17 # init_device.argtypes = [ctypes.c_char_p]
#      18 # init_device.restype = ctypes.c_void_p
#      19
#      20 # Call the function
#      21 sDevSn = "61CF-02"
#
# File /usr/lib/python3.10/ctypes/__init__.py:452, in LibraryLoader.LoadLibrary(self, name)
#     451 def LoadLibrary(self, name):
# ...

# %%
import pandas as pd

# Read the CSV file into a pandas DataFrame
df = pd.read_csv('SDKIntegrationConfig.csv')

color_map = {"R":"Red", "G":"Green", "B":"Blue"}
# Iterate over each row in the DataFrame
for index, row in df.iterrows():
    # Retrieve values from each column
    color_we_focus = color_map[row['Color_we_focus']]
    greylevel_we_fixed_on = row['greylevel_we_fixed_on']
    grey_level_R = row['grey_level_R']
    grey_level_G = row['grey_level_G']
    grey_level_B = row['grey_level_B']
    aperture = row['aperture']
    ET = row['ET']
    
    image_path = f"{color_we_focus}{greylevel_we_fixed_on}/{grey_level_R}_{grey_level_G}_{grey_level_B}.bmp"
    image_paths.append(image_path)

    # Print the values as an example
    print(f"Color_we_focus: {color_we_focus}")
    print(f"greylevel_we_fixed_on: {greylevel_we_fixed_on}")
    print(f"grey_level_R: {grey_level_R}")
    print(f"grey_level_G: {grey_level_G}")
    print(f"grey_level_B: {grey_level_B}")
    print(f"aperture: {aperture}")
    print(f"ET: {ET}")
    print(f"Image Path: {image_path}")
    print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 19
#      16 ET = row['ET']
#      18 image_path = f"{color_we_focus}{greylevel_we_fixed_on}/{grey_level_R}_{grey_level_G}_{grey_level_B}.bmp"
# ---> 19 image_paths.append(image_path)
#      21 # Print the values as an example
#      22 print(f"Color_we_focus: {color_we_focus}")
#
# NameError: name 'image_paths' is not defined

# %%
import socket
import pandas as pd

class Client:
    def __init__(self, server_ip, server_port):
        self.server_ip = server_ip
        self.server_port = server_port
        self.client_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
        self.client_socket.settimeout(10)
        
    def connect(self):
        try:
            self.client_socket.connect((self.server_ip, self.server_port))
            print("Connection successful!")
        except ConnectionRefusedError:
            print("Connection refused. Make sure the server is running and the IP/port are correct.")
        except socket.timeout:
            print("Connection timed out. Check your network settings.")
        except Exception as e:
            print("An error occurred:", str(e))
    
    def send_initialization_request(self):
        request_data = {
            'STX': 0x02,
            'Command': 'IC',
            'CmdType': 'C',
            'Acknowledge': '',
            'Reserve': '',
            'ETX': 0x03
        }
        
        request_bytes = bytes([request_data['STX']]) + \
                       request_data['Command'].encode('ascii') + \
                       request_data['CmdType'].encode('ascii') + \
                       request_data['Acknowledge'].encode('ascii') + \
                       request_data['Reserve'].encode('ascii') + \
                       bytes([request_data['ETX']])
        request_bytes =  bytes.fromhex('02 2C 49 43 2C 43 2C 2C 03')
        print("initialization request: {}".format(request_bytes))
        self.client_socket.sendall(request_bytes)
        response = self.client_socket.recv(1024)
        print(response)
    
    def send_power_on_request(self):
#         b'\x02SP,C,,,1,1,1,1\x03'
        
        request_data = {
            'STX': 0x02,
            'Command': 'SP,',
            'CmdType': 'C,',
            'Acknowledge': ',',
            'Reserve': ',',
            'RackNo': "1,",
            'PgNo': "1,",
            'ChannelNo': "1,",
            'Operation Code': "1",
            'ETX': 0x03
        }
        
        request_bytes = bytes([request_data['STX']]) + \
                   request_data['Command'].encode() + \
                   request_data['CmdType'].encode() + \
                   request_data['Acknowledge'].encode() + \
                   request_data['Reserve'].encode() + \
                   request_data['RackNo'].encode() + \
                   request_data['PgNo'].encode() + \
                   request_data['ChannelNo'].encode() + \
                   request_data['Operation Code'].encode() + \
                   bytes([request_data['ETX']])
            
#         request_bytes = bytes.fromhex('02 53 50 2C 43 2C 2C 2C 31 2C 31 2C 31 2C 31 03')
        print("power on request: {}".format(request_bytes))
        self.client_socket.sendall(request_bytes)
        response = self.client_socket.recv(1024)
        print(response)
        
    def send_power_off_request(self):
        request_data = {
            'STX': 0x02,
            'Command': 'SP,',
            'CmdType': 'C,',
            'Acknowledge': ',',
            'Reserve': ',',
            'RackNo': "1,",
            'PgNo': "1,",
            'ChannelNo': "1,",
            'Operation Code': "0",
            'ETX': 0x03
        }
        
        request_bytes = bytes([request_data['STX']]) + \
                   request_data['Command'].encode() + \
                   request_data['CmdType'].encode() + \
                   request_data['Acknowledge'].encode() + \
                   request_data['Reserve'].encode() + \
                   request_data['RackNo'].encode() + \
                   request_data['PgNo'].encode() + \
                   request_data['ChannelNo'].encode() + \
                   request_data['Operation Code'].encode() + \
                   bytes([request_data['ETX']])

        print("power off request: {}".format(request_bytes))
        self.client_socket.sendall(request_bytes)
        response = self.client_socket.recv(1024)
        print(response)
    
    def send_image_swap_request(self, image_path):
        request_data = {
            'STX': 0x02,
            'Command': 'NP,',
            'CmdType': 'C,',
            'Acknowledge': ',',
            'Reserve': ',',
            'RackNo': "1,",
            'PgNo': "1,",
            'ChannelNo': "1,",
            'PatternName': image_path,
            'ETX': 0x03
        }
        
        request_bytes = bytes([request_data['STX']]) + \
                       request_data['Command'].encode('ascii') + \
                       request_data['CmdType'].encode('ascii') + \
                       request_data['Acknowledge'].encode('ascii') + \
                       request_data['Reserve'].encode('ascii') + \
                       request_data['RackNo'].encode() + \
                       request_data['PgNo'].encode() + \
                       request_data['ChannelNo'].encode() + \
                       request_data['PatternName'].encode('ascii') + \
                       bytes([request_data['ETX']])
        
        print("power image_swap request: {}".format(request_bytes))
        self.client_socket.sendall(request_bytes)
        response = self.client_socket.recv(1024)
        print(response)
    
    def close(self):
        self.client_socket.close()

# Create a client instance
client = Client('127.0.0.1', 9999)

# Connect to the server
client.connect()

# Send the power switch request
client.send_power_on_request()

# Send the power switch request
client.send_power_off_request()

# Loop through all images
# Iterate over each row in the DataFrame
for index, row in df.iterrows():
    # Retrieve values from each column
    color_we_focus = color_map[row['Color_we_focus']]
    greylevel_we_fixed_on = row['greylevel_we_fixed_on']
    grey_level_R = row['grey_level_R']
    grey_level_G = row['grey_level_G']
    grey_level_B = row['grey_level_B']
    aperture = row['aperture']
    ET = row['ET']
    
    image_path = f"{color_we_focus}{greylevel_we_fixed_on}/{grey_level_R}_{grey_level_G}_{grey_level_B}.bmp"
    client.send_image_swap_request(image_path)
    
    #now we send aperture and ET settings to the camera, and have it take a picture
    

# Close the connection
client.close()
# Out:
# Connection successful!
# power on request: b'\x02SP,C,,,1,1,1,1\x03'
# b'\x02SP,S,0,1,1,1,1\x03'
# power off request: b'\x02SP,C,,,1,1,1,0\x03'
# b'\x02SP,S,0,0,1,1,1\x03'

# %%
request_bytes = bytes.fromhex('02 53 50 2C 43 2C 2C 2C 31 2C 31 2C 31 2C 30 03')
print(request_bytes)
# Out:
# b'\x02SP,C,,,1,1,1,0\x03'

# %%
request_data = {
    'STX': 0x02,
    'Command': 'SP',
    'CmdType': 'C',
    'Acknowledge': '',
    'Reserve': '',
    'RackNo': "1",
    'PgNo': "1",
    'ChannelNo': "1",
    'Operation Code': "1",
    'ETX': 0x03
}

        
byte_string = bytes([
    request_data['STX'],
    ord(request_data['Command']),
    ord(request_data['CmdType']),
    ord(request_data['Acknowledge']),
    ord(request_data['Reserve']),
    int(request_data['RackNo']),
    int(request_data['PgNo']),
    int(request_data['ChannelNo']),
    int(request_data['Operation Code']),
    request_data['ETX']
])

print(byte_string)

print(byte_string == b'\x02SP,C,1,1,1,1,1\x03')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 17
#       1 request_data = {
#       2     'STX': 0x02,
#       3     'Command': 'SP',
#    (...)
#      11     'ETX': 0x03
#      12 }
#      15 byte_string = bytes([
#      16     request_data['STX'],
# ---> 17     ord(request_data['Command']),
#      18     ord(request_data['CmdType']),
#      19     ord(request_data['Acknowledge']),
#      20     ord(request_data['Reserve']),
#      21     int(request_data['RackNo']),
#      22     int(request_data['PgNo']),
#      23     int(request_data['ChannelNo']),
#      24     int(request_data['Operation Code']),
#      25     request_data['ETX']
#      26 ])
#      28 print(byte_string)
#      30 print(byte_string == b'\x02SP,C,1,1,1,1,1\x03')
#
# TypeError: ord() expected a character, but string of length 2 found

# %%
# 开关电和切图指令：
# 开电：
# [02]SP,C,,,1,1,1,1[03]
# 关电：
# [02]SP,C,,,1,1,1,0[03]
# 按序号切图（比如列表内的第2张图）：
# [02]CP,C,,,1,1,1,2[03]
# 按图片名字切图（比如图片名字是1.bpm）：
# [02]NP,C,,,1,1,1,1.bmp[03]

#         b'\x02SP,C,,,1,1,1,0\x03'
def send_power_switch_request(self):
    request_data = {
        'STX': 0x02,
        'Command': 'SP,',
        'CmdType': 'C,',
        'Acknowledge': ',',
        'Reserve': ',',
        'RackNo': "1,",
        'PgNo': "1,",
        'ChannelNo': "1,",
        'Operation Code': "1,",
        'ETX': 0x03
    }
        
    request_bytes = bytes([request_data['STX']]) + \
                   request_data['Command'].encode() + \
                   request_data['CmdType'].encode() + \
                   request_data['Acknowledge'].encode() + \
                   request_data['Reserve'].encode() + \
                   request_data['RackNo'].encode() + \
                   request_data['PgNo'].encode() + \
                   request_data['ChannelNo'].encode() + \
                   request_data['Operation Code'].encode() + \
                   bytes([request_data['ETX']])
        
self.client_socket.sendall(request_bytes)
response = self.client_socket.recv(1024)
print(response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 37
#      13     request_data = {
#      14         'STX': 0x02,
#      15         'Command': 'SP,',
#    (...)
#      23         'ETX': 0x03
#      24     }
#      26     request_bytes = bytes([request_data['STX']]) + \
#      27                    request_data['Command'].encode() + \
#      28                    request_data['CmdType'].encode() + \
#    (...)
#      34                    request_data['Operation Code'].encode() + \
#      35                    bytes([request_data['ETX']])
# ---> 37 self.client_socket.sendall(request_bytes)
#      38 response = self.client_socket.recv(1024)
#      39 print(response)
#
# NameError: name 'self' is not defined
